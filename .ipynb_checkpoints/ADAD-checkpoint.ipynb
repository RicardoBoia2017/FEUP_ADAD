# %%
import requests
import pandas as pd
import datetime as dt

# %%
matches = pd.read_csv('matches.csv')
# Out:
#      match_id  home_id         home_name  away_id          away_name  \
# 0      152587        7         Liverpool      492       Norwich City
# 1      152653       14   West Ham United       12    Manchester City
# 2      152730        1   AFC Bournemouth      281   Sheffield United
# 3      152731        8           Burnley        4        Southampton
# 4      152732        3    Crystal Palace       20            Everton
# ..        ...      ...               ...      ...                ...
# 374    201875        6    Leicester City       19  Manchester United
# 375    201876       12   Manchester City      492       Norwich City
# 376    201877        9  Newcastle United        7          Liverpool
# 377    201878        4       Southampton      281   Sheffield United
# 378    201879       14   West Ham United      495        Aston Villa
#
#      home_ft_goals  away_ft_goals  home_ht_goals  away_ht_goals  \
# 0                4              1              0              0
# 1                0              5              0              1
# 2                1              1              0              0
# 3                3              0              0              0
# 4                0              0              0              0
# ..             ...            ...            ...            ...
# 374              0              2              0              0
# 375              5              0              2              0
# 376              1              3              1              1
# 377              3              1              0              1
# 378              1              1              0              0
#
#            stadium_name  city  country continent competition_name    type  \
# 0               Anfield  City  England    Europe   Premier League  League
# 1                   NaN  City  England    Europe   Premier League  League
# 2                   NaN  City  England    Europe   Premier League  League
# 3             Turf Moor  City  England    Europe   Premier League  League
# 4                   NaN  City  England    Europe   Premier League  League
# ..                  ...   ...      ...       ...              ...     ...
# 374  King Power Stadium  City  England    Europe   Premier League  League
# 375      Etihad Stadium  City  England    Europe   Premier League  League
# 376     St. James' Park  City  England    Europe   Premier League  League
# 377  St. Mary's Stadium  City  England    Europe   Premier League  League
# 378      London Stadium  City  England    Europe   Premier League  League
#
#      tier  hour  minute  day dayofweek  month  year got_stats  home_yc  \
# 0       1    19       0    9    Friday      8  2019         F      NaN
# 1       1    11      30   10  Saturday      8  2019         F      NaN
# 2       1    14       0   10  Saturday      8  2019         F      NaN
# 3       1    14       0   10  Saturday      8  2019         F      NaN
# 4       1    14       0   10  Saturday      8  2019         F      NaN
# ..    ...   ...     ...  ...       ...    ...   ...       ...      ...
# 374     1    15       0   26    Sunday      7  2020         F      NaN
# 375     1    15       0   26    Sunday      7  2020         F      NaN
# 376     1    15       0   26    Sunday      7  2020         F      NaN
# 377     1    15       0   26    Sunday      7  2020         F      NaN
# 378     1    15       0   26    Sunday      7  2020         F      NaN
#
#      away_yc  home_rc  away_rc  home_possession  away_possession  home_shots  \
# 0        NaN      NaN      NaN              NaN              NaN         NaN
# 1        NaN      NaN      NaN              NaN              NaN         NaN
# 2        NaN      NaN      NaN              NaN              NaN         NaN
# 3        NaN      NaN      NaN              NaN              NaN         NaN
# 4        NaN      NaN      NaN              NaN              NaN         NaN
# ..       ...      ...      ...              ...              ...         ...
# 374      NaN      NaN      NaN              NaN              NaN         NaN
# 375      NaN      NaN      NaN              NaN              NaN         NaN
# 376      NaN      NaN      NaN              NaN              NaN         NaN
# 377      NaN      NaN      NaN              NaN              NaN         NaN
# 378      NaN      NaN      NaN              NaN              NaN         NaN
#
#      away_shots  home_shots_on_target  away_shots_on_target  home_fouls  \
# 0           NaN                   NaN                   NaN         NaN
# 1           NaN                   NaN                   NaN         NaN
# 2           NaN                   NaN                   NaN         NaN
# 3           NaN                   NaN                   NaN         NaN
# 4           NaN                   NaN                   NaN         NaN
# ..          ...                   ...                   ...         ...
# 374         NaN                   NaN                   NaN         NaN
# 375         NaN                   NaN                   NaN         NaN
# 376         NaN                   NaN                   NaN         NaN
# 377         NaN                   NaN                   NaN         NaN
# 378         NaN                   NaN                   NaN         NaN
#
#      away_fouls  home_attacks  away_attacks
# 0           NaN           NaN           NaN
# 1           NaN           NaN           NaN
# 2           NaN           NaN           NaN
# 3           NaN           NaN           NaN
# 4           NaN           NaN           NaN
# ..          ...           ...           ...
# 374         NaN           NaN           NaN
# 375         NaN           NaN           NaN
# 376         NaN           NaN           NaN
# 377         NaN           NaN           NaN
# 378         NaN           NaN           NaN
#
# [379 rows x 37 columns]

# %%
#Sends request to get past matches

def pastMatchesRequest(date_from, date_to, competition_id, page):
    url = "https://live-score-api.p.rapidapi.com/scores/history.json"

    headers = {
        'x-rapidapi-key': "ce0be8d538msh30ecb1b4c0fca98p105373jsn1e40f1d8d1ec",
        'x-rapidapi-host': "live-score-api.p.rapidapi.com",
        }

    params = {
        'key': "MC8uSjXafFUAGJqM",
        'secret': "xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj",
        'from': date_from,
        'to': date_to,
        'competition_id': competition_id,
        'page': page
    }

    return requests.request("GET", url, params = params,headers=headers).json()

# %%
#Sends request to get stats from a specific match

def matchStatsRequest(match_id):
    url = "https://live-score-api.p.rapidapi.com/matches/stats.json"

    headers = {
        'x-rapidapi-key': "ce0be8d538msh30ecb1b4c0fca98p105373jsn1e40f1d8d1ec",
        'x-rapidapi-host': "live-score-api.p.rapidapi.com",
        }

    params = {
        'key': "MC8uSjXafFUAGJqM",
        'secret': "xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj",
        'match_id': match_id
    }

    return requests.request("GET", url, params = params,headers=headers).json()

# %%
#Stores information from 'Past matches' on a list

def addMatchInfo(response):
    for info in response['data']['match']:
        if(info['ht_score'] == ''):
            info['ht_score'] = '0 - 0'
        matches_list.append([
            info['id'],
            info['home_id'],
            info['home_name'],
            info['away_id'],
            info['away_name'],
            info['score'].split(' -')[0],
            info['score'].split('- ')[1],
            info['ht_score'].split(' -')[0],
            info['ht_score'].split('- ')[1],
            info['location'],
            'City',
            'England',
            'Europe',
            'Premier League',
            'League',
            '1',
            info['scheduled'].split(':')[0],
            info['scheduled'].split(':')[1],
            info['date'].split('-')[2],
            dt.date(int(info['date'].split('-')[0]),int(info['date'].split('-')[1]),int(info['date'].split('-')[2])).strftime("%A"),
            info['date'].split('-')[1],
            info['date'].split('-')[0],
        ])

# %%
#Updates df with 'Match stats' information

def addMatchStats(rowIndex, matchId):
    response = matchStatsRequest(matchId)
    if(response['data'] != []):
        matches.at[rowIndex,'home_yc'] = response['data']['yellow_cards'].split(':')[0]
        matches.at[rowIndex,'away_yc'] = response['data']['yellow_cards'].split(':')[1]
        matches.at[rowIndex,'home_rc'] = response['data']['red_cards'].split(':')[0]
        matches.at[rowIndex,'away_rc'] = response['data']['red_cards'].split(':')[1]
        matches.at[rowIndex,'home_possession'] = response['data']['possesion'].split(':')[0]
        matches.at[rowIndex,'away_possession'] = response['data']['possesion'].split(':')[1]
        matches.at[rowIndex,'home_shots'] = response['data']['attempts_on_goal'].split(':')[0] 
        matches.at[rowIndex,'away_shots'] = response['data']['attempts_on_goal'].split(':')[1] 
        if(response['data']['shots_on_target'] is None):
            matches.at[rowIndex,'home_shots_on_target'] = int(response['data']['attempts_on_goal'].split(':')[0]) - int(response['data']['shots_off_target'].split(':')[0])
            matches.at[rowIndex,'away_shots_on_target'] = int(response['data']['attempts_on_goal'].split(':')[1]) - int(response['data']['shots_off_target'].split(':')[1])
        else:
            matches.at[rowIndex,'home_shots_on_target'] = response['data']['shots_on_target'].split(':')[0]
            matches.at[rowIndex,'away_shots_on_target'] = response['data']['shots_on_target'].split(':')[1]
        matches.at[rowIndex,'home_fouls'] = response['data']['fauls'].split(':')[0]
        matches.at[rowIndex,'away_fouls'] = response['data']['fauls'].split(':')[1]
        matches.at[rowIndex,'home_attacks'] = response['data']['attacks'].split(':')[0]
        matches.at[rowIndex,'away_attacks'] = response['data']['attacks'].split(':')[1]
    matches.at[rowIndex,'got_stats'] = 'T'

# %%
#Gets past matches and stores it on a df

def getMatches(date_from, date_to, competition_id):
    page = 1
    
    response = pastMatchesRequest(date_from, date_to, competition_id, page)
    addMatchInfo(response)
    
    total_pages = response['data']['total_pages']
    page += 1
    
    while(page <= total_pages):
        response = sendRequest(date_from, date_to, competition_id, page),
        addToList(response),
        page += 1
    
    df = pd.DataFrame(matches_list, columns =['match_id','home_id','home_name','away_id','away_name','home_ft_goals','away_ft_goals','home_ht_goals','away_ht_goals','stadium_name','city','country','continent','competition_name','type','tier','hour','minute','day','dayofweek','month','year'])
    df

# %%
#Gets match stats from top to bottom until an error is found

def getMatchStats():
    while(True):
        rowIndex = matches[matches['got_stats'] == 'F'].head(1).index
        matchId = matches[matches['got_stats'] == 'F'].head(1)['match_id']
        addMatchStats(rowIndex, matchId)

# %%
matches_list = []
getMatches('2019-08-01','2020-08-01',2)
#r = pastMatchesRequest('2019-08-01','2020-08-01',2, 13)
#addToList(r)
#df = pd.DataFrame(matches_list, columns =['match_id','home_id','home_name','away_id','away_name','home_ft_goals','away_ft_goals','home_ht_goals','away_ht_goals','stadium_name','city','country','continent','competition_name','type','tier','hour','minute','day','dayofweek','month','year'])
#df
#df.to_csv('matches.csv', index=False);
# Out:
# {'success': True,
#  'data': {'match': [{'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-09 20:57:03',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=492&key=MC8uSjXafFUAGJqM&team1_id=7',
#     'away_id': 492,
#     'home_name': 'Liverpool',
#     'score': '4 - 1',
#     'home_id': 7,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=152587&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-09 20:36:03',
#     'fixture_id': 1285088,
#     'scheduled': '19:00',
#     'ht_score': '',
#     'et_score': '',
#     'date': '2019-08-09',
#     'id': 152587,
#     'ft_score': '4 - 1',
#     'location': 'Anfield',
#     'outcomes': {'half_time': None, 'full_time': '1', 'extra_time': None},
#     'time': 'FT',
#     'away_name': 'Norwich City',
#     'league_id': 25},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-10 13:22:17',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=12&key=MC8uSjXafFUAGJqM&team1_id=14',
#     'away_id': 12,
#     'home_name': 'West Ham United',
#     'score': '0 - 5',
#     'home_id': 14,
#     'fixture_id': 1285089,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=152653&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-10 11:15:13',
#     'league_id': 25,
#     'scheduled': '11:30',
#     'ht_score': '0 - 1',
#     'et_score': '',
#     'date': '2019-08-10',
#     'id': 152653,
#     'ft_score': '0 - 5',
#     'outcomes': {'full_time': '2', 'extra_time': None, 'half_time': '2'},
#     'time': 'FT',
#     'away_name': 'Manchester City',
#     'location': None},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-10 15:53:03',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=281&key=MC8uSjXafFUAGJqM&team1_id=1',
#     'away_id': 281,
#     'home_name': 'AFC Bournemouth',
#     'score': '1 - 1',
#     'home_id': 1,
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=152730&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-10 13:45:27',
#     'fixture_id': 1285093,
#     'scheduled': '14:00',
#     'ht_score': '0 - 0',
#     'et_score': '',
#     'time': 'FT',
#     'competition_name': 'Premier League',
#     'date': '2019-08-10',
#     'id': 152730,
#     'ft_score': '1 - 1',
#     'outcomes': {'full_time': 'X', 'extra_time': None, 'half_time': 'X'},
#     'league_id': 25,
#     'away_name': 'Sheffield United',
#     'location': ''},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-10 15:53:18',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=4&key=MC8uSjXafFUAGJqM&team1_id=8',
#     'away_id': 4,
#     'home_name': 'Burnley',
#     'score': '3 - 0',
#     'home_id': 8,
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=152731&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-10 13:45:27',
#     'fixture_id': 1285092,
#     'scheduled': '14:00',
#     'ht_score': '0 - 0',
#     'et_score': '',
#     'time': 'FT',
#     'competition_name': 'Premier League',
#     'date': '2019-08-10',
#     'id': 152731,
#     'ft_score': '3 - 0',
#     'outcomes': {'full_time': '1', 'extra_time': None, 'half_time': 'X'},
#     'league_id': 25,
#     'away_name': 'Southampton',
#     'location': 'Turf Moor'},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-10 15:55:17',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=20&key=MC8uSjXafFUAGJqM&team1_id=3',
#     'away_id': 20,
#     'home_name': 'Crystal Palace',
#     'score': '0 - 0',
#     'home_id': 3,
#     'fixture_id': 1285094,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=152732&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-10 13:45:27',
#     'league_id': 25,
#     'scheduled': '14:00',
#     'ht_score': '0 - 0',
#     'et_score': '',
#     'date': '2019-08-10',
#     'id': 152732,
#     'ft_score': '0 - 0',
#     'outcomes': {'full_time': 'X', 'extra_time': None, 'half_time': 'X'},
#     'time': 'FT',
#     'away_name': 'Everton',
#     'location': None},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-10 15:51:26',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=2&key=MC8uSjXafFUAGJqM&team1_id=11',
#     'away_id': 2,
#     'home_name': 'Watford',
#     'score': '0 - 3',
#     'home_id': 11,
#     'fixture_id': 1285091,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=152733&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-10 13:45:27',
#     'league_id': 25,
#     'scheduled': '14:00',
#     'ht_score': '0 - 1',
#     'et_score': '',
#     'date': '2019-08-10',
#     'id': 152733,
#     'ft_score': '0 - 3',
#     'outcomes': {'full_time': '2', 'extra_time': None, 'half_time': '2'},
#     'time': 'FT',
#     'away_name': 'Brighton Hove Albion',
#     'location': 'Vicarage Road Stadium'},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-10 18:23:02',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=495&key=MC8uSjXafFUAGJqM&team1_id=15',
#     'away_id': 495,
#     'home_name': 'Tottenham Hotspur',
#     'score': '3 - 1',
#     'home_id': 15,
#     'fixture_id': 1285095,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=152906&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-10 16:15:21',
#     'league_id': 25,
#     'scheduled': '16:30',
#     'ht_score': '0 - 1',
#     'et_score': '',
#     'date': '2019-08-10',
#     'id': 152906,
#     'ft_score': '3 - 1',
#     'outcomes': {'full_time': '1', 'extra_time': None, 'half_time': '2'},
#     'time': 'FT',
#     'away_name': 'Aston Villa',
#     'location': 'Tottenham Hotspur Stadium'},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-11 14:51:27',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=497&key=MC8uSjXafFUAGJqM&team1_id=6',
#     'away_id': 497,
#     'home_name': 'Leicester City',
#     'score': '0 - 0',
#     'home_id': 6,
#     'fixture_id': 1285090,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=153107&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-11 12:45:15',
#     'league_id': 25,
#     'scheduled': '13:00',
#     'ht_score': '0 - 0',
#     'et_score': '',
#     'date': '2019-08-11',
#     'id': 153107,
#     'ft_score': '0 - 0',
#     'outcomes': {'full_time': 'X', 'extra_time': None, 'half_time': 'X'},
#     'time': 'FT',
#     'away_name': 'Wolverhampton Wanderers',
#     'location': 'King Power Stadium'},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-11 14:53:02',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=18&key=MC8uSjXafFUAGJqM&team1_id=9',
#     'away_id': 18,
#     'home_name': 'Newcastle United',
#     'score': '0 - 1',
#     'home_id': 9,
#     'fixture_id': 1285096,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=153108&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-11 12:45:15',
#     'league_id': 25,
#     'scheduled': '13:00',
#     'ht_score': '0 - 0',
#     'et_score': '',
#     'date': '2019-08-11',
#     'id': 153108,
#     'ft_score': '0 - 1',
#     'outcomes': {'full_time': '2', 'extra_time': None, 'half_time': 'X'},
#     'time': 'FT',
#     'away_name': 'Arsenal',
#     'location': "St. James' Park"},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-11 17:23:02',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=17&key=MC8uSjXafFUAGJqM&team1_id=19',
#     'away_id': 17,
#     'home_name': 'Manchester United',
#     'score': '4 - 0',
#     'home_id': 19,
#     'fixture_id': 1285097,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=153181&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-11 15:15:22',
#     'league_id': 25,
#     'scheduled': '15:30',
#     'ht_score': '1 - 0',
#     'et_score': '',
#     'date': '2019-08-11',
#     'id': 153181,
#     'ft_score': '4 - 0',
#     'outcomes': {'full_time': '1', 'extra_time': None, 'half_time': '1'},
#     'time': 'FT',
#     'away_name': 'Chelsea',
#     'location': 'Old Trafford'},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-17 13:23:16',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=8&key=MC8uSjXafFUAGJqM&team1_id=18',
#     'away_id': 8,
#     'home_name': 'Arsenal',
#     'score': '2 - 1',
#     'home_id': 18,
#     'fixture_id': 1285106,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=154078&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-17 11:15:15',
#     'league_id': 25,
#     'scheduled': '11:30',
#     'ht_score': '1 - 1',
#     'et_score': '',
#     'date': '2019-08-17',
#     'id': 154078,
#     'ft_score': '2 - 1',
#     'outcomes': {'full_time': '1', 'extra_time': None, 'half_time': 'X'},
#     'time': 'FT',
#     'away_name': 'Burnley',
#     'location': 'Emirates Stadium'},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-17 15:57:08',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=1&key=MC8uSjXafFUAGJqM&team1_id=495',
#     'away_id': 1,
#     'home_name': 'Aston Villa',
#     'score': '1 - 2',
#     'home_id': 495,
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=154144&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-17 13:45:21',
#     'fixture_id': 1285105,
#     'scheduled': '14:00',
#     'ht_score': '0 - 2',
#     'et_score': '',
#     'time': 'FT',
#     'competition_name': 'Premier League',
#     'date': '2019-08-17',
#     'id': 154144,
#     'ft_score': '1 - 2',
#     'outcomes': {'full_time': '2', 'extra_time': None, 'half_time': '2'},
#     'league_id': 25,
#     'away_name': 'AFC Bournemouth',
#     'location': ''},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-17 15:51:48',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=14&key=MC8uSjXafFUAGJqM&team1_id=2',
#     'away_id': 14,
#     'home_name': 'Brighton Hove Albion',
#     'score': '1 - 1',
#     'home_id': 2,
#     'fixture_id': 1285103,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=154145&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-17 13:45:21',
#     'league_id': 25,
#     'scheduled': '14:00',
#     'ht_score': '0 - 0',
#     'et_score': '',
#     'date': '2019-08-17',
#     'id': 154145,
#     'ft_score': '1 - 1',
#     'outcomes': {'full_time': 'X', 'extra_time': None, 'half_time': 'X'},
#     'time': 'FT',
#     'away_name': 'West Ham United',
#     'location': 'The American Express Community Stadium'},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-17 15:53:23',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=11&key=MC8uSjXafFUAGJqM&team1_id=20',
#     'away_id': 11,
#     'home_name': 'Everton',
#     'score': '1 - 0',
#     'home_id': 20,
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=154146&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-17 13:45:22',
#     'fixture_id': 1285104,
#     'scheduled': '14:00',
#     'ht_score': '1 - 0',
#     'et_score': '',
#     'time': 'FT',
#     'competition_name': 'Premier League',
#     'date': '2019-08-17',
#     'id': 154146,
#     'ft_score': '1 - 0',
#     'outcomes': {'full_time': '1', 'extra_time': None, 'half_time': '1'},
#     'league_id': 25,
#     'away_name': 'Watford',
#     'location': 'Goodison Park'},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-17 15:53:06',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=9&key=MC8uSjXafFUAGJqM&team1_id=492',
#     'away_id': 9,
#     'home_name': 'Norwich City',
#     'score': '3 - 1',
#     'home_id': 492,
#     'fixture_id': 1285099,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=154147&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-17 13:45:22',
#     'league_id': 25,
#     'scheduled': '14:00',
#     'ht_score': '1 - 0',
#     'et_score': '',
#     'date': '2019-08-17',
#     'id': 154147,
#     'ft_score': '3 - 1',
#     'outcomes': {'full_time': '1', 'extra_time': None, 'half_time': '1'},
#     'time': 'FT',
#     'away_name': 'Newcastle United',
#     'location': None},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-17 15:53:07',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=7&key=MC8uSjXafFUAGJqM&team1_id=4',
#     'away_id': 7,
#     'home_name': 'Southampton',
#     'score': '1 - 2',
#     'home_id': 4,
#     'fixture_id': 1285102,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=154148&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-17 13:45:22',
#     'league_id': 25,
#     'scheduled': '14:00',
#     'ht_score': '0 - 1',
#     'et_score': '',
#     'date': '2019-08-17',
#     'id': 154148,
#     'ft_score': '1 - 2',
#     'outcomes': {'full_time': '2', 'extra_time': None, 'half_time': '2'},
#     'time': 'FT',
#     'away_name': 'Liverpool',
#     'location': None},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-17 18:26:23',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=15&key=MC8uSjXafFUAGJqM&team1_id=12',
#     'away_id': 15,
#     'home_name': 'Manchester City',
#     'score': '2 - 2',
#     'home_id': 12,
#     'fixture_id': 1285101,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=154312&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-17 16:15:27',
#     'league_id': 25,
#     'scheduled': '16:30',
#     'ht_score': '2 - 1',
#     'et_score': '',
#     'date': '2019-08-17',
#     'id': 154312,
#     'ft_score': '2 - 2',
#     'outcomes': {'full_time': 'X', 'extra_time': None, 'half_time': '1'},
#     'time': 'FT',
#     'away_name': 'Tottenham Hotspur',
#     'location': 'Etihad Stadium'},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-18 14:57:02',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=3&key=MC8uSjXafFUAGJqM&team1_id=281',
#     'away_id': 3,
#     'home_name': 'Sheffield United',
#     'score': '1 - 0',
#     'home_id': 281,
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=154521&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-18 12:45:33',
#     'fixture_id': 1285098,
#     'scheduled': '13:00',
#     'ht_score': '0 - 0',
#     'et_score': '',
#     'time': 'FT',
#     'competition_name': 'Premier League',
#     'date': '2019-08-18',
#     'id': 154521,
#     'ft_score': '1 - 0',
#     'outcomes': {'full_time': '1', 'extra_time': None, 'half_time': 'X'},
#     'league_id': 25,
#     'away_name': 'Crystal Palace',
#     'location': 'Bramall Lane'},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-18 17:22:09',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=6&key=MC8uSjXafFUAGJqM&team1_id=17',
#     'away_id': 6,
#     'home_name': 'Chelsea',
#     'score': '1 - 1',
#     'home_id': 17,
#     'fixture_id': 1285107,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=154598&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-18 15:15:26',
#     'league_id': 25,
#     'scheduled': '15:30',
#     'ht_score': '1 - 0',
#     'et_score': '',
#     'date': '2019-08-18',
#     'id': 154598,
#     'ft_score': '1 - 1',
#     'outcomes': {'full_time': 'X', 'extra_time': None, 'half_time': '1'},
#     'time': 'FT',
#     'away_name': 'Leicester City',
#     'location': None},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-19 20:52:03',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=19&key=MC8uSjXafFUAGJqM&team1_id=497',
#     'away_id': 19,
#     'home_name': 'Wolverhampton Wanderers',
#     'score': '1 - 1',
#     'home_id': 497,
#     'fixture_id': 1285100,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=154792&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-19 18:45:10',
#     'league_id': 25,
#     'scheduled': '19:00',
#     'ht_score': '0 - 1',
#     'et_score': '',
#     'date': '2019-08-19',
#     'id': 154792,
#     'ft_score': '1 - 1',
#     'outcomes': {'full_time': 'X', 'extra_time': None, 'half_time': '2'},
#     'time': 'FT',
#     'away_name': 'Manchester United',
#     'location': None},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-23 20:55:01',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=20&key=MC8uSjXafFUAGJqM&team1_id=495',
#     'away_id': 20,
#     'home_name': 'Aston Villa',
#     'score': '2 - 0',
#     'home_id': 495,
#     'fixture_id': 1285115,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=155216&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-23 18:45:31',
#     'league_id': 25,
#     'scheduled': '19:00',
#     'ht_score': '1 - 0',
#     'et_score': '',
#     'date': '2019-08-23',
#     'id': 155216,
#     'ft_score': '2 - 0',
#     'outcomes': {'full_time': '1', 'extra_time': None, 'half_time': '1'},
#     'time': 'FT',
#     'away_name': 'Everton',
#     'location': 'Villa Park'},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-24 13:26:19',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=17&key=MC8uSjXafFUAGJqM&team1_id=492',
#     'away_id': 17,
#     'home_name': 'Norwich City',
#     'score': '2 - 3',
#     'home_id': 492,
#     'fixture_id': 1285111,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=155293&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-24 11:15:15',
#     'league_id': 25,
#     'scheduled': '11:30',
#     'ht_score': '2 - 2',
#     'et_score': '',
#     'date': '2019-08-24',
#     'id': 155293,
#     'ft_score': '2 - 3',
#     'outcomes': {'full_time': '2', 'extra_time': None, 'half_time': 'X'},
#     'time': 'FT',
#     'away_name': 'Chelsea',
#     'location': None},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-24 15:55:05',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=4&key=MC8uSjXafFUAGJqM&team1_id=2',
#     'away_id': 4,
#     'home_name': 'Brighton Hove Albion',
#     'score': '0 - 2',
#     'home_id': 2,
#     'fixture_id': 1285116,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=155372&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-24 13:46:01',
#     'league_id': 25,
#     'scheduled': '14:00',
#     'ht_score': '0 - 0',
#     'et_score': '',
#     'date': '2019-08-24',
#     'id': 155372,
#     'ft_score': '0 - 2',
#     'outcomes': {'full_time': '2', 'extra_time': None, 'half_time': 'X'},
#     'time': 'FT',
#     'away_name': 'Southampton',
#     'location': 'The American Express Community Stadium'},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-24 15:56:40',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=3&key=MC8uSjXafFUAGJqM&team1_id=19',
#     'away_id': 3,
#     'home_name': 'Manchester United',
#     'score': '1 - 2',
#     'home_id': 19,
#     'fixture_id': 1285114,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=155373&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-24 13:46:01',
#     'league_id': 25,
#     'scheduled': '14:00',
#     'ht_score': '0 - 1',
#     'et_score': '',
#     'date': '2019-08-24',
#     'id': 155373,
#     'ft_score': '1 - 2',
#     'outcomes': {'full_time': '2', 'extra_time': None, 'half_time': '2'},
#     'time': 'FT',
#     'away_name': 'Crystal Palace',
#     'location': None},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-24 15:53:01',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=6&key=MC8uSjXafFUAGJqM&team1_id=281',
#     'away_id': 6,
#     'home_name': 'Sheffield United',
#     'score': '1 - 2',
#     'home_id': 281,
#     'fixture_id': 1285108,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=155374&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-24 13:46:02',
#     'league_id': 25,
#     'scheduled': '14:00',
#     'ht_score': '0 - 1',
#     'et_score': '',
#     'date': '2019-08-24',
#     'id': 155374,
#     'ft_score': '1 - 2',
#     'outcomes': {'full_time': '2', 'extra_time': None, 'half_time': '2'},
#     'time': 'FT',
#     'away_name': 'Leicester City',
#     'location': None},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-24 15:54:49',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=14&key=MC8uSjXafFUAGJqM&team1_id=11',
#     'away_id': 14,
#     'home_name': 'Watford',
#     'score': '1 - 3',
#     'home_id': 11,
#     'fixture_id': 1285112,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=155375&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-24 13:46:02',
#     'league_id': 25,
#     'scheduled': '14:00',
#     'ht_score': '1 - 1',
#     'et_score': '',
#     'date': '2019-08-24',
#     'id': 155375,
#     'ft_score': '1 - 3',
#     'outcomes': {'full_time': '2', 'extra_time': None, 'half_time': 'X'},
#     'time': 'FT',
#     'away_name': 'West Ham United',
#     'location': None},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-24 18:23:02',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=18&key=MC8uSjXafFUAGJqM&team1_id=7',
#     'away_id': 18,
#     'home_name': 'Liverpool',
#     'score': '3 - 1',
#     'home_id': 7,
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=155580&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-24 16:15:48',
#     'fixture_id': 1285117,
#     'scheduled': '16:30',
#     'ht_score': '1 - 0',
#     'et_score': '',
#     'time': 'FT',
#     'competition_name': 'Premier League',
#     'date': '2019-08-24',
#     'id': 155580,
#     'ft_score': '3 - 1',
#     'outcomes': {'full_time': '1', 'extra_time': None, 'half_time': '1'},
#     'league_id': 25,
#     'away_name': 'Arsenal',
#     'location': 'Anfield'},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-25 14:56:33',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=12&key=MC8uSjXafFUAGJqM&team1_id=1',
#     'away_id': 12,
#     'home_name': 'AFC Bournemouth',
#     'score': '1 - 3',
#     'home_id': 1,
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=155811&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-25 12:45:17',
#     'fixture_id': 1285113,
#     'scheduled': '13:00',
#     'ht_score': '1 - 2',
#     'et_score': '',
#     'time': 'FT',
#     'competition_name': 'Premier League',
#     'date': '2019-08-25',
#     'id': 155811,
#     'ft_score': '1 - 3',
#     'outcomes': {'full_time': '2', 'extra_time': None, 'half_time': '2'},
#     'league_id': 25,
#     'away_name': 'Manchester City',
#     'location': 'Vitality Stadium'},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-25 17:25:03',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=9&key=MC8uSjXafFUAGJqM&team1_id=15',
#     'away_id': 9,
#     'home_name': 'Tottenham Hotspur',
#     'score': '0 - 1',
#     'home_id': 15,
#     'fixture_id': 1285109,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=155932&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-25 15:15:29',
#     'league_id': 25,
#     'scheduled': '15:30',
#     'ht_score': '0 - 1',
#     'et_score': '',
#     'date': '2019-08-25',
#     'id': 155932,
#     'ft_score': '0 - 1',
#     'outcomes': {'full_time': '2', 'extra_time': None, 'half_time': '2'},
#     'time': 'FT',
#     'away_name': 'Newcastle United',
#     'location': 'Tottenham Hotspur Stadium'},
#    {'competition_id': 2,
#     'status': 'FINISHED',
#     'last_changed': '2019-08-25 17:26:33',
#     'h2h': 'https://livescore-api.com/api-client/teams/head2head.json?secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&team2_id=8&key=MC8uSjXafFUAGJqM&team1_id=497',
#     'away_id': 8,
#     'home_name': 'Wolverhampton Wanderers',
#     'score': '1 - 1',
#     'home_id': 497,
#     'fixture_id': 1285110,
#     'competition_name': 'Premier League',
#     'events': 'https://livescore-api.com/api-client/scores/events.json?id=155933&key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj',
#     'added': '2019-08-25 15:15:29',
#     'league_id': 25,
#     'scheduled': '15:30',
#     'ht_score': '0 - 1',
#     'et_score': '',
#     'date': '2019-08-25',
#     'id': 155933,
#     'ft_score': '1 - 1',
#     'outcomes': {'full_time': 'X', 'extra_time': None, 'half_time': '2'},
#     'time': 'FT',
#     'away_name': 'Burnley',
#     'location': 'Molineux Stadium'}],
#   'total_pages': 13,
#   'prev_page': False,
#   'next_page': 'https://livescore-api.com/api-client/scores/history.json?key=MC8uSjXafFUAGJqM&secret=xRuVIJwAPNVMqsYc46HXqF7Fk2f1MGNj&page=2&from=2019-08-01&to=2020-08-01&competition_id=2'}}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-51f6679a1daf> in <module>
#       1 matches_list = []
#       2 stats_list = []
# ----> 3 getMatches('2019-08-01','2020-08-01',2)
#       4 #r = pastMatchesRequest('2019-08-01','2020-08-01',2, 13)
#       5 #addToList(r)
#
# <ipython-input-103-4e80ecffb073> in getMatches(date_from, date_to, competition_id)
#      12
#      13     while(page <= total_pages):
# ---> 14         response = sendRequest(date_from, date_to, competition_id, page),
#      15         addToList(response),
#      16         page += 1
#
# NameError: name 'sendRequest' is not defined

# %%
getMatchStats()
matches.to_csv('matches.csv', index=False);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-155-50942aa9e3f7> in <module>
# ----> 1 getMatchStats()
#
# <ipython-input-137-df90940d090a> in getMatchStats()
#       3         rowIndex = matches[matches['got_stats'] == 'F'].head(1).index
#       4         matchId = matches[matches['got_stats'] == 'F'].head(1)['match_id']
# ----> 5         addMatchStats(rowIndex, matchId)
#
# <ipython-input-154-0888ff98ef4a> in addMatchStats(rowIndex, matchId)
#       3 def addMatchStats(rowIndex, matchId):
#       4     response = matchStatsRequest(matchId)
# ----> 5     if(response['data'] != []):
#       6         matches.at[rowIndex,'home_yc'] = response['data']['yellow_cards'].split(':')[0]
#       7         matches.at[rowIndex,'away_yc'] = response['data']['yellow_cards'].split(':')[1]
#
# KeyError: 'data'

# %%
matches.loc[matches['got_stats'] == 'F']
# Out:
#      match_id  home_id                home_name  away_id  \
# 278    194509       18                  Arsenal       14
# 279    194510        3           Crystal Palace       11
# 280    194511      281         Sheffield United      492
# 281    194512        4              Southampton        9
# 282    194513      497  Wolverhampton Wanderers        2
# ..        ...      ...                      ...      ...
# 374    201875        6           Leicester City       19
# 375    201876       12          Manchester City      492
# 376    201877        9         Newcastle United        7
# 377    201878        4              Southampton      281
# 378    201879       14          West Ham United      495
#
#                   away_name  home_ft_goals  away_ft_goals  home_ht_goals  \
# 278         West Ham United              1              0              0
# 279                 Watford              1              0              1
# 280            Norwich City              1              0              1
# 281        Newcastle United              0              1              0
# 282  Brighton & Hove Albion              0              0              0
# ..                      ...            ...            ...            ...
# 374       Manchester United              0              2              0
# 375            Norwich City              5              0              2
# 376               Liverpool              1              3              1
# 377        Sheffield United              3              1              0
# 378             Aston Villa              1              1              0
#
#      away_ht_goals        stadium_name  city  country continent  \
# 278              0    Emirates Stadium  City  England    Europe
# 279              0       Selhurst Park  City  England    Europe
# 280              0        Bramall Lane  City  England    Europe
# 281              0  St. Mary's Stadium  City  England    Europe
# 282              0    Molineux Stadium  City  England    Europe
# ..             ...                 ...   ...      ...       ...
# 374              0  King Power Stadium  City  England    Europe
# 375              0      Etihad Stadium  City  England    Europe
# 376              1     St. James' Park  City  England    Europe
# 377              1  St. Mary's Stadium  City  England    Europe
# 378              0      London Stadium  City  England    Europe
#
#     competition_name    type  tier  hour  minute  day dayofweek  month  year  \
# 278   Premier League  League     1    15       0    7  Saturday      3  2020
# 279   Premier League  League     1    15       0    7  Saturday      3  2020
# 280   Premier League  League     1    15       0    7  Saturday      3  2020
# 281   Premier League  League     1    15       0    7  Saturday      3  2020
# 282   Premier League  League     1    15       0    7  Saturday      3  2020
# ..               ...     ...   ...   ...     ...  ...       ...    ...   ...
# 374   Premier League  League     1    15       0   26    Sunday      7  2020
# 375   Premier League  League     1    15       0   26    Sunday      7  2020
# 376   Premier League  League     1    15       0   26    Sunday      7  2020
# 377   Premier League  League     1    15       0   26    Sunday      7  2020
# 378   Premier League  League     1    15       0   26    Sunday      7  2020
#
#     got_stats home_yc away_yc home_rc away_rc home_possession away_possession  \
# 278         F     NaN     NaN     NaN     NaN             NaN             NaN
# 279         F     NaN     NaN     NaN     NaN             NaN             NaN
# 280         F     NaN     NaN     NaN     NaN             NaN             NaN
# 281         F     NaN     NaN     NaN     NaN             NaN             NaN
# 282         F     NaN     NaN     NaN     NaN             NaN             NaN
# ..        ...     ...     ...     ...     ...             ...             ...
# 374         F     NaN     NaN     NaN     NaN             NaN             NaN
# 375         F     NaN     NaN     NaN     NaN             NaN             NaN
# 376         F     NaN     NaN     NaN     NaN             NaN             NaN
# 377         F     NaN     NaN     NaN     NaN             NaN             NaN
# 378         F     NaN     NaN     NaN     NaN             NaN             NaN
#
#     home_shots away_shots home_shots_on_target away_shots_on_target  \
# 278        NaN        NaN                  NaN                  NaN
# 279        NaN        NaN                  NaN                  NaN
# 280        NaN        NaN                  NaN                  NaN
# 281        NaN        NaN                  NaN                  NaN
# 282        NaN        NaN                  NaN                  NaN
# ..         ...        ...                  ...                  ...
# 374        NaN        NaN                  NaN                  NaN
# 375        NaN        NaN                  NaN                  NaN
# 376        NaN        NaN                  NaN                  NaN
# 377        NaN        NaN                  NaN                  NaN
# 378        NaN        NaN                  NaN                  NaN
#
#     home_fouls away_fouls home_attacks away_attacks
# 278        NaN        NaN          NaN          NaN
# 279        NaN        NaN          NaN          NaN
# 280        NaN        NaN          NaN          NaN
# 281        NaN        NaN          NaN          NaN
# 282        NaN        NaN          NaN          NaN
# ..         ...        ...          ...          ...
# 374        NaN        NaN          NaN          NaN
# 375        NaN        NaN          NaN          NaN
# 376        NaN        NaN          NaN          NaN
# 377        NaN        NaN          NaN          NaN
# 378        NaN        NaN          NaN          NaN
#
# [101 rows x 37 columns]

# %%
matches.loc[matches['got_stats'] == 'T']
# Out:
#      match_id  home_id          home_name  away_id                away_name  \
# 0      152587        7          Liverpool      492             Norwich City
# 1      152653       14    West Ham United       12          Manchester City
# 2      152730        1    AFC Bournemouth      281         Sheffield United
# 3      152731        8            Burnley        4              Southampton
# 4      152732        3     Crystal Palace       20                  Everton
# ..        ...      ...                ...      ...                      ...
# 273    193008       14    West Ham United        4              Southampton
# 274    193309       11            Watford        7                Liverpool
# 275    193555       20            Everton       19        Manchester United
# 276    193556       15  Tottenham Hotspur      497  Wolverhampton Wanderers
# 277    194379        7          Liverpool        1          AFC Bournemouth
#
#      home_ft_goals  away_ft_goals  home_ht_goals  away_ht_goals  \
# 0                4              1              0              0
# 1                0              5              0              1
# 2                1              1              0              0
# 3                3              0              0              0
# 4                0              0              0              0
# ..             ...            ...            ...            ...
# 273              3              1              2              1
# 274              3              0              0              0
# 275              1              1              1              1
# 276              2              3              2              1
# 277              2              1              2              1
#
#                   stadium_name  city  country continent competition_name  \
# 0                      Anfield  City  England    Europe   Premier League
# 1                          NaN  City  England    Europe   Premier League
# 2                          NaN  City  England    Europe   Premier League
# 3                    Turf Moor  City  England    Europe   Premier League
# 4                          NaN  City  England    Europe   Premier League
# ..                         ...   ...      ...       ...              ...
# 273             London Stadium  City  England    Europe   Premier League
# 274      Vicarage Road Stadium  City  England    Europe   Premier League
# 275              Goodison Park  City  England    Europe   Premier League
# 276  Tottenham Hotspur Stadium  City  England    Europe   Premier League
# 277                    Anfield  City  England    Europe   Premier League
#
#        type  tier  hour  minute  day dayofweek  month  year got_stats home_yc  \
# 0    League     1    19       0    9    Friday      8  2019         T     NaN
# 1    League     1    11      30   10  Saturday      8  2019         T     NaN
# 2    League     1    14       0   10  Saturday      8  2019         T     NaN
# 3    League     1    14       0   10  Saturday      8  2019         T     NaN
# 4    League     1    14       0   10  Saturday      8  2019         T     NaN
# ..      ...   ...   ...     ...  ...       ...    ...   ...       ...     ...
# 273  League     1    15       0   29  Saturday      2  2020         T       1
# 274  League     1    17      30   29  Saturday      2  2020         T       0
# 275  League     1    14       0    1    Sunday      3  2020         T       3
# 276  League     1    14       0    1    Sunday      3  2020         T       3
# 277  League     1    12      30    7  Saturday      3  2020         T       0
#
#     away_yc home_rc away_rc home_possession away_possession home_shots  \
# 0       NaN     NaN     NaN             NaN             NaN        NaN
# 1       NaN     NaN     NaN             NaN             NaN        NaN
# 2       NaN     NaN     NaN             NaN             NaN        NaN
# 3       NaN     NaN     NaN             NaN             NaN        NaN
# 4       NaN     NaN     NaN             NaN             NaN        NaN
# ..      ...     ...     ...             ...             ...        ...
# 273       1       0       0              34              66         13
# 274       0       0       0              30              70         10
# 275       4       0       0              44              56          8
# 276       2       0       0              64              36          6
# 277       1       0       0              75              25         10
#
#     away_shots home_shots_on_target away_shots_on_target home_fouls  \
# 0          NaN                  NaN                  NaN        NaN
# 1          NaN                  NaN                  NaN        NaN
# 2          NaN                  NaN                  NaN        NaN
# 3          NaN                  NaN                  NaN        NaN
# 4          NaN                  NaN                  NaN        NaN
# ..         ...                  ...                  ...        ...
# 273          4                    8                    2          8
# 274          6                    5                    1          4
# 275          9                    3                    5         11
# 276          9                    3                    3         12
# 277          5                    6                    4         10
#
#     away_fouls home_attacks away_attacks
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
# ..         ...          ...          ...
# 273         11           80          122
# 274          8           71           98
# 275         11           78           80
# 276         14          138           89
# 277         12          109           60
#
# [278 rows x 37 columns]
